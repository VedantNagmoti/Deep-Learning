# %% [markdown]
# # Data Scaling
#
# ### Standardize :
#
# + Mean centering
# + standered deviation = 1
# + mean = 0
#
# **If we don't know a minimum value and maximum value of then use standardization**
#
# **If data is normally distributed**
#
#  Ex : Salary
#
#
# ### Normalize :
#
# + Min value = 0
# + max value = 1
#
# **If we know a minimum value and maximum value of a variable then use normalization**
#
# Ex: CGPA

# %% [markdown]
# ## Cost function will become symmetrical
#
# Due to which training becomes faster
#
# gradient descent can easily converge
