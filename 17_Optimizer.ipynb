# %% [markdown]
# # Optimizer
#
# ## Role of Optimizer
#
# + Optimization
# + Loss Minimization
# + Updating Weights
#
# ## Types of optimizers
#
# + Batch Gradient Descent
# + Stochastic Gradient Descent
# + Mini Batch Gradient Descent
#
# ## Challenges
# + Deciding correct learning rate value
# + Learning rate same for all weights, some weight may need to decrese less than other weight to reach correct prediction
# + Local minima
# + saddle point
#
# ## What next ?
# Exponentially weighted moving average
#
# + Momentum
# + Adagrad
# + NAG
# + RMSProp
# + Adam

# %% [markdown]
# ------------------------------------------------------------------------------------------------
# # Exponentially weighted moving average
#
# The Exponentially Weighted Moving Average (EWMA) is a statistical technique for modeling or smoothing time-series data that assigns exponentially decreasing weights to older observations while prioritizing recent data.
