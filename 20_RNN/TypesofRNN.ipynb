# %% [markdown]
# # Types of RNN
#
# 1. Many to One - Simple RNN - Sentiment Analysis, IMDB rating
# 2. One to Many - Image to Caption project
# 3. Many to Many - Seq to Seq model -
#
#         1. Variable length output(Google translate)(Encoder-Decoder Architecture)
#         2. Same length output(NER)

# %% [markdown]
# # Problems with RNN
#
# + Problem of long term dependency(Causes due to Vanishing Gradient Problem)
# + Stagneted training(Exploding gradient problem)
